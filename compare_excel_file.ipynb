# %%
import pandas as pd

# %%
plumber = pd.read_excel('plumber.xlsx')

# %%
retailer = pd.read_excel('Retailer.xlsx')

# %%
plumber
# Out:
#                Name                       Email Id     Mobile No.  \
# 0      Rahel Robert          rahelrobert@yahoo.com  91-9213555722
# 1         manugupta            manu_0803@yahoo.com  91-9958673297
# 2         lejo john              lijo_87@yahoo.com  91-9818290798
# 3      Ravi Prakash              ravi046@yahoo.com  91-9811959479
# 4       Jatin Kalra   gunjanrefrigeration@vsnl.com  91-9810110959
# ...             ...                            ...            ...
# 19994    deepa rani      deepajhamb@indiatimes.com  91-9810498190
# 19995  nitin sharma      greatnitinsharma@sify.com  91-9871667776
# 19996    Madhan Raj            madhan2k1@gmail.com  91-9940689120
# 19997    Parag Jain           paragjain9@gmail.com  91-9350293626
# 19998  suresh kumar  sureshkumar240484@yahoo.co.in  91-9313858837
#
#            Current Location  Gender  \
# 0                     Delhi  Female
# 1                     Delhi  Female
# 2                 Faridabad    Male
# ...

# %%
plumber
# Out:
#                Name                       Email Id     Mobile No.  \
# 0      Rahel Robert          rahelrobert@yahoo.com  91-9213555722
# 1         manugupta            manu_0803@yahoo.com  91-9958673297
# 2         lejo john              lijo_87@yahoo.com  91-9818290798
# 3      Ravi Prakash              ravi046@yahoo.com  91-9811959479
# 4       Jatin Kalra   gunjanrefrigeration@vsnl.com  91-9810110959
# ...             ...                            ...            ...
# 19994    deepa rani      deepajhamb@indiatimes.com  91-9810498190
# 19995  nitin sharma      greatnitinsharma@sify.com  91-9871667776
# 19996    Madhan Raj            madhan2k1@gmail.com  91-9940689120
# 19997    Parag Jain           paragjain9@gmail.com  91-9350293626
# 19998  suresh kumar  sureshkumar240484@yahoo.co.in  91-9313858837
#
#            Current Location  Gender  \
# 0                     Delhi  Female
# 1                     Delhi  Female
# 2                 Faridabad    Male
# ...

# %%
plumber.equals(retailer)
# Out:
# False

# %%
compare = plumber.values == retailer.values
# Out:
# <ipython-input-8-0698d4f0eee2>:1: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   compare = plumber.values == retailer.values

# %%
print(compare)
# Out:
# False

# %%
comp_plum = list(plumber["Mobile No."])
comp_retail = retailer[~retailer["Mobile No."].isin(comp_plum)]

# %%
comp_retail
# Out:
#                     Name                         Email Id     Mobile No.  \
# 0          monika gautam        monica_lisa4u@yahoo.co.in  91-9891744715
# 1         MuditBhatnagar         muditbhatnagar@gmail.com  91-9873646677
# 2       Mrityunjay Kumar       godhelpme_1@indiatimes.com  91-9899644735
# 3        priyanka kapoor              prrikap@yahoo.co.in  91-9899950788
# 4         Vikrant Shukla  vikrant_shukla19@rediffmail.com  91-9891571591
# ...                  ...                              ...            ...
# 19995        rajiv singh            ritesh1104@epatra.com  91-9810854637
# 19996    AbhilashaShukla         shuklabhilasha@gmail.com  91-9871825059
# 19997       vanita rawat            rawatvanita@gmail.com  91-9350580585
# 19998  devesh srivastava             devesh.mba@gmail.com  91-9868702505
# 19999     akhilesh singh          akhilesh.iftm@gmail.com  91-9810405585
#
#            Current Location  Gender  \
# 0      Noida/ Greater Noida  Female
# ...

# %%
sheet_1 = pd.read_excel('sheet_1.xlsx')

# %%
sheet_2 = pd.read_excel('Sheet_2.xlsx')

# %%
sheet_1
# Out:
#                 Name              Current Location     Mobile No.
# 0       Rahel Robert         rahelrobert@yahoo.com  91-9213555722
# 1          manugupta           manu_0803@yahoo.com  91-9958673297
# 2          lejo john             lijo_87@yahoo.com  91-9818290798
# 3       Ravi Prakash             ravi046@yahoo.com  91-9811959479
# 4        Jatin Kalra  gunjanrefrigeration@vsnl.com  91-9810110959
# 5     ApurvaTripathi    apurvatripathi@hotmail.com  91-9811798030
# 6     ashish trivedi             taj_mba@yahoo.com  91-9985177502
# 7   Sharmistha Singh    ssharma_kiams4@yahoo.co.in  91-9868266773
# 8      vandana madan      vandana_net_id@yahoo.com  91-9911197334
# 9        SUNIL KHERA    sunil_khera@rediffmail.com  91-9811676935
# 10        Amit Kapur   amit_kapur43@rediffmail.com     9810969205

# %%
sheet_2
# Out:
#                  Name             Current Location     Mobile No.
# 0        Rahel Robert        rahelrobert@yahoo.com  91-9213555722
# 1           manugupta          manu_0803@yahoo.com  91-9958673297
# 2           lejo john            lijo_87@yahoo.com  91-9818290798
# 3    Sharmistha Singh   ssharma_kiams4@yahoo.co.in  91-9868266773
# 4       vandana madan     vandana_net_id@yahoo.com  91-9911197334
# 5         SUNIL KHERA   sunil_khera@rediffmail.com  91-9811676935
# 6          Amit Kapur  amit_kapur43@rediffmail.com     9810969205
# 7      Kailash Khatri           kckhatri@yahoo.com  91-9810295412
# 8         Bipin Pande      bchpande@indiatimes.com  91-9810133148
# 9   ajay kumar gautam        akg812001@yahoo.co.in  91-9213479854
# 10       sonalikapoor        sonali38459@gmail.com  91-9990571730

# %%
comp  = list(sheet_1["Mobile No."])
comp_both = sheet_2[~sheet_2["Mobile No."].isin(comp)]

# %%
comp_both
# Out:
#                  Name         Current Location     Mobile No.
# 7      Kailash Khatri       kckhatri@yahoo.com  91-9810295412
# 8         Bipin Pande  bchpande@indiatimes.com  91-9810133148
# 9   ajay kumar gautam    akg812001@yahoo.co.in  91-9213479854
# 10       sonalikapoor    sonali38459@gmail.com  91-9990571730
